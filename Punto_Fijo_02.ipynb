# %% [markdown]
# Definiendo g1
#
#
# $x = \frac{5}{2x-1}$

# %%
import matplotlib.pyplot as plt

# %%
def g2(x):
    return 5/(2*x-1)

# %%
x_vec=float ( input ("Digite el valor inicial: "))
print (x_vec)
n=float ( input ("Digite el numero de iteraciones: "))
print (n)
#x_vec=[]
#x_vec.append(0)
contador = 0
error=1
#error_vec=[]
#error_vec.append(1)
criterio_paro = 0.0001
# Out:
# Digite el valor inicial: 0
# 0.0
# Digite el numero de iteraciones: 20
# 20.0

# %%
while(error > criterio_paro):
    x_temp = g2(x_vec)
    #x_vec(x_temp)
    error = abs(x_vec-x_vec)
    #error_vec.append(e_temp)
    contador= contador + 1
    x_vec=x_temp
#if contador>= criterio_paro:
  #print ("false")
while (contador <= n):
   x_temp = g2(x_vec)
   error = abs(x_vec-x_vec)
   contador= contador + 1
   x_vec=x_temp
   print ("iteracion: ", x_vec)
if contador >= n:
  print ("false")
plt.plot(g2(x_vec))
#plt.show()
plt.grid()
# Out:
# iteracion:  -0.45454545454545453
# iteracion:  -2.619047619047619
# iteracion:  -0.8015267175572519
# iteracion:  -1.9208211143695015
# iteracion:  -1.0327074500302846
# iteracion:  -1.6311005730092867
# iteracion:  -1.1731027768763618
# iteracion:  -1.4942297834610216
# iteracion:  -1.253616820254888
# iteracion:  -1.4256250117609075
# iteracion:  -1.2982797713630907
# iteracion:  -1.3902174955262983
# iteracion:  -1.322599122014749
# iteracion:  -1.3716675103170435
# iteracion:  -1.3357073231326875
# iteracion:  -1.361872869654231
# iteracion:  -1.3427339969051033
# iteracion:  -1.356679805223534
# iteracion:  -1.3464895740054725
# iteracion:  -1.3539204527306963
# false

# %%
import matplotlib.pyplot as plt
import math

# %%
def g2(x):
  return ((2*x**2)-5)

# %%
x_v=[]
x_v.append(0)
c= int(input("Digite el valor inicial: "))
#error=[]
error.append(float(input("Digite el error: ")))
criterio= float(input ("Digite el criterio de paro: "))
n= int(input ("Digite numero de iteraciones: "))
# Out:
# Digite el valor inicial: 1
# Digite el error: 0
# Digite el criterio de paro: 0.0001
# Digite numero de iteraciones: 5

# %%
while( error[c] > criterio):
   x_t=g2(x_v[c])
   x_v.append(x_t)
   temm=abs(x_v[c+1]-x_v[c])
   error.append(temm)
   c+=1
   if (x_v[c]>2000):
    ite=False
    print("False")
   else:
    if (x_v[c]<2000):
      ite=True
      print ("false")

# %%
plt.plot(x_v)
plt.grid()
